# %% [raw]
# ---
# authors:
# - admin
# categories: []
# date: "2019-07-01T00:00:00Z"
# draft: false
# featured: false
# #lastmod: "2019-04-17T00:00:00Z"
# projects: []
# #subtitle: ''
# tags:
# - Jupyter
# title: 'Using Jupyter Notebook with Hugo'
# ---

# %%
using Plots
gr()
using PlotThemes
theme(:ggplot2)

# %%
x = 1:0.01:30
y = sin.(x);

# %%
plot(x,y)
